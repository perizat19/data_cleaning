# %%
import pandas as pd

df = pd.read_csv('pokemon_data.csv')
df.head(15)
# Out:
#      #                       Name Type 1  Type 2  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison  45      49       49
# 1    2                    Ivysaur  Grass  Poison  60      62       63
# 2    3                   Venusaur  Grass  Poison  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison  80     100      123
# 4    4                 Charmander   Fire     NaN  39      52       43
# 5    5                 Charmeleon   Fire     NaN  58      64       58
# 6    6                  Charizard   Fire  Flying  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying  78     104       78
# 9    7                   Squirtle  Water     NaN  44      48       65
# 10   8                  Wartortle  Water     NaN  59      63       80
# 11   9                  Blastoise  Water     NaN  79      83      100
# ...

# %%
df[['Name', 'Attack', 'Speed']].head(10)
# Out:
#                         Name  Attack  Speed
# 0                  Bulbasaur      49     45
# 1                    Ivysaur      62     60
# 2                   Venusaur      82     80
# 3      VenusaurMega Venusaur     100     80
# 4                 Charmander      52     65
# 5                 Charmeleon      64     80
# 6                  Charizard      84    100
# 7  CharizardMega Charizard X     130    100
# 8  CharizardMega Charizard Y     104    100
# 9                   Squirtle      48     43

# %% [markdown]
# Printing the row with the index 5

# %%
df.loc[5]
# Out:
# #                      5
# Name          Charmeleon
# Type 1              Fire
# Type 2               NaN
# HP                    58
# Attack                64
# Defense               58
# Sp. Atk               80
# Sp. Def               65
# Speed                 80
# Generation             1
# Legendary          False
# Name: 5, dtype: object

# %% [markdown]
# Printing specific ceil from the dataset (row 3 column 1)

# %%
df.iloc[3, 1]
# Out:
# 'VenusaurMega Venusaur'

# %% [markdown]
# Here I use for loop to iterate through whole dataset and get only names with their index

# %%
for index, row in df.iterrows():
    print(index, row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %% [markdown]
# Here I write a command to get only the rows whose 'Type 1' column is 'Psychic'

# %%
df.loc[df['Type 1'] == 'Psychic'].head(10)
# Out:
#        #                   Name   Type 1    Type 2   HP  Attack  Defense  \
# 68    63                   Abra  Psychic       NaN   25      20       15
# 69    64                Kadabra  Psychic       NaN   40      35       30
# 70    65               Alakazam  Psychic       NaN   55      50       45
# 71    65  AlakazamMega Alakazam  Psychic       NaN   55      50       65
# 104   96                Drowzee  Psychic       NaN   60      48       45
# 105   97                  Hypno  Psychic       NaN   85      73       70
# 131  122               Mr. Mime  Psychic     Fairy   40      45       65
# 162  150                 Mewtwo  Psychic       NaN  106     110       90
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 68       105       55     90           1      False
# 69       120       70    105           1      False
# ...

# %%
df.loc[df['HP'] == 55].tail(10)
# Out:
#        #                 Name    Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 601  541             Swadloon       Bug   Grass  55      63       90       50
# 627  566               Archen      Rock  Flying  55     112       45       74
# 633  572             Minccino    Normal     NaN  55      50       40       40
# 648  587               Emolga  Electric  Flying  55      75       60       75
# 653  592             Frillish     Water   Ghost  55      40       50       65
# 666  605               Elgyem   Psychic     NaN  55      55       55       85
# 674  613              Cubchoo       Ice     NaN  55      70       40       60
# 697  636             Larvesta       Bug    Fire  55      85       55       50
# 785  711  GourgeistSmall Size     Ghost   Grass  55      85      122       58
# 788  712             Bergmite       Ice     NaN  55      69       85       32
#
#      Sp. Def  Speed  Generation  Legendary
# 601       80     42           5      False
# ...

# %% [markdown]
# # Sorting/Describing data

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %% [markdown]
#  Values in 'Name' column are sorted in alphabetic ascending order

# %%
df.sort_values('Name')
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Sorting in descending order the 'Generation' column

# %%
df.sort_values('Generation', ascending=False)
# Out:
#        #       Name    Type 1   Type 2   HP  Attack  Defense  Sp. Atk  \
# 799  721  Volcanion      Fire    Water   80     110      120      130
# 738  670    Floette     Fairy      NaN   54      45       47       75
# 740  672     Skiddo     Grass      NaN   66      65       48       62
# 741  673     Gogoat     Grass      NaN  123     100       62       97
# 742  674    Pancham  Fighting      NaN   67      82       62       46
# ..   ...        ...       ...      ...  ...     ...      ...      ...
# 110  102  Exeggcute     Grass  Psychic   60      40       80       60
# 109  101  Electrode  Electric      NaN   60      50       70       80
# 108  100    Voltorb  Electric      NaN   40      30       50       55
# 107   99    Kingler     Water      NaN   55     130      115       50
# 0      1  Bulbasaur     Grass   Poison   45      49       49       65
#
#      Sp. Def  Speed  Generation  Legendary
# 799       90     70           6       True
# ...

# %% [markdown]
# Sorting two columns in ascending and descending order

# %%
df.sort_values(['Type 1', 'HP'], ascending=[1, 0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # Making changes to the data

# %% [markdown]
# Creating new column named 'Total'

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %% [markdown]
# Droping the 'Total' column

# %%
df = df.drop(columns='Total')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# Another way to create a new column

# %%
df['Total'] = df.iloc[:, 4:10].sum(axis=1)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %% [markdown]
# Changing the order of the columns

# %%
cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]] + [cols[-2]] + cols[4:12]]
df
# Out:
#        #                   Name   Type 1  Type 2  Total  Legendary  HP  \
# 0      1              Bulbasaur    Grass  Poison    318      False  45
# 1      2                Ivysaur    Grass  Poison    405      False  60
# 2      3               Venusaur    Grass  Poison    525      False  80
# 3      3  VenusaurMega Venusaur    Grass  Poison    625      False  80
# 4      4             Charmander     Fire     NaN    309      False  39
# ..   ...                    ...      ...     ...    ...        ...  ..
# 795  719                Diancie     Rock   Fairy    600       True  50
# 796  719    DiancieMega Diancie     Rock   Fairy    700       True  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600       True  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680       True  80
# 799  721              Volcanion     Fire   Water    600       True  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# Legendary       0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  Legendary  HP  \
# 0      1              Bulbasaur    Grass  Poison    318      False  45
# 1      2                Ivysaur    Grass  Poison    405      False  60
# 2      3               Venusaur    Grass  Poison    525      False  80
# 3      3  VenusaurMega Venusaur    Grass  Poison    625      False  80
# 4      4             Charmander     Fire     NaN    309      False  39
# ..   ...                    ...      ...     ...    ...        ...  ..
# 795  719                Diancie     Rock   Fairy    600       True  50
# 796  719    DiancieMega Diancie     Rock   Fairy    700       True  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600       True  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680       True  80
# 799  721              Volcanion     Fire   Water    600       True  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
mode = df['Type 2'].mode()
mode
# Out:
# 0    Flying
# Name: Type 2, dtype: object

# %%
df['Type 2'].fillna('Flying', inplace=True)
df['Type 2']
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_14584\3156964280.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Type 2'].fillna('Flying', inplace=True)
# C:\Users\admin\AppData\Local\Temp\ipykernel_14584\3156964280.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Type 2'].fillna('Flying', inplace=True)
# ...

# %%
df.isnull().sum()
# Out:
# #             0
# Name          0
# Type 1        0
# Type 2        0
# Total         0
# Legendary     0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  Type 2  Total  Legendary   HP  Attack  \
# 0      1              Bulbasaur  Grass  Poison    318      False   45      49
# 1      2                Ivysaur  Grass  Poison    405      False   60      62
# 2      3               Venusaur  Grass  Poison    525      False   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison    625      False   80     100
# 48    43                 Oddish  Grass  Poison    320      False   45      50
# 49    44                  Gloom  Grass  Poison    395      False   60      65
# 50    45              Vileplume  Grass  Poison    490      False   75      80
# 75    69             Bellsprout  Grass  Poison    300      False   50      75
# 76    70             Weepinbell  Grass  Poison    390      False   65      90
# 77    71             Victreebel  Grass  Poison    490      False   80     105
# 344  315                Roselia  Grass  Poison    400      False   50      60
# ...
